# %% [markdown]
# # Rice seedlings detection and counting
#
# This notebook use xxx_CNN model and compare with the classic CV baseline

# %% [markdown]
# # 1. Install, import packages and wandb setup

# %%
# %pip install geoai-py wandb
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.37.2-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.0.8)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geoai-py) (8.3.1)
# Collecting contextily (from geoai-py)
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.8.3)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.1.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.4.1)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.4.0)
# Collecting leafmap>=0.57.1 (from geoai-py)
#   Downloading leafmap-0.62.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from geoai-py)
#   Downloading localtileserver-1.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0)
# Collecting maplibre (from geoai-py)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.13.0.92)
# Collecting overturemaps (from geoai-py)
#   Downloading overturemaps-1.0.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting planetary-computer (from geoai-py)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py) (23.0.1)
# Collecting pystac-client (from geoai-py)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.5.0)
# Collecting rioxarray (from geoai-py)
#   Downloading rioxarray-0.22.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.1)
# Collecting smoothify (from geoai-py)
#   Downloading smoothify-0.2.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.25)
# Requirement already satisfied: tokenizers>=0.22.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.22.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0+cu128)
# Collecting torchgeo (from geoai-py)
#   Downloading torchgeo-0.9.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.67.3)
# Requirement already satisfied: transformers>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (5.0.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.9.2)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.53.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.0.2)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0->geoai-py) (2026.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (1.3.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (0.24.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.12.45)
# Collecting duckdb>=1.4.1 (from leafmap>=0.57.1->geoai-py)
#   Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (5.2.1)
# Requirement already satisfied: geojson in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (3.2.0)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Collecting ipyvue>=1.12.0 (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (8.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.11.0)
# Collecting whiteboxgui (from leafmap>=0.57.1->geoai-py)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (2025.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (1.16.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (6.5.13)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (2.4.1)
# Collecting mercantile (from contextily->geoai-py)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (11.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.5.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (2.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (3.13.3)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (2.12.5)
# Requirement already satisfied: simpervisor>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (1.0.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (5.14.3)
# Requirement already satisfied: fastapi>=0.100.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.133.0)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.41.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (3.1.6)
# Collecting jupyter-loopback>=0.3.3 (from jupyter-loopback[comm]>=0.3.3->localtileserver->geoai-py)
#   Downloading jupyter_loopback-0.3.3-py3-none-any.whl.metadata (7.6 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Downloading rio_tiler-9.0.6-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py)
#   Downloading rio_cogeo-7.0.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->geoai-py)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->geoai-py) (3.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geoai-py) (3.6.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from maplibre->geoai-py) (0.8.2)
# Collecting eval-type-backport (from maplibre->geoai-py)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: colorama>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from overturemaps->geoai-py) (0.4.6)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from overturemaps->geoai-py) (3.11.7)
# Collecting pyfiglet>=1.0.2 (from overturemaps->geoai-py)
#   Downloading pyfiglet-1.0.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py)
#   Downloading pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (2025.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pystac-client->geoai-py) (2.9.0.post0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (3.3.2)
# Collecting xarray>=2026.2 (from rioxarray->geoai-py)
#   Downloading xarray-2026.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2026.2.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (0.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->geoai-py) (0.25.0+cu128)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (1.14.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->geoai-py) (1.3.5)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.8.2)
# Collecting jsonargparse>=4.35 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading jsonargparse-4.48.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: kornia>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.8.2)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py)
#   Downloading lightly-1.5.23-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# Collecting lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2 (from torchgeo->geoai-py)
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# Collecting segmentation-models-pytorch>=0.5 (from torchgeo->geoai-py)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: torchmetrics>=1.2 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (1.9.0)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.52.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0->geoai-py) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0->geoai-py) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=3.0->geoai-py) (0.16.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (7.34.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->localtileserver->geoai-py) (3.0.3)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (0.17.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading typeshed_client-2.11.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap>=0.57.1->geoai-py) (0.15.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (6.4.5)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.10.4)
# Requirement already satisfied: overrides in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (7.7.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.18.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.9.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.8.2->torchgeo->geoai-py) (0.1.10)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.6.1)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading aenum-3.1.17-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2->torchgeo->geoai-py) (0.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py) (1.4.9)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0->geoai-py) (2025.3)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->geoai-py) (4.26.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geoai-py) (1.3.0)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap>=0.57.1->geoai-py) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap>=0.57.1->geoai-py) (4.13.5)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily->geoai-py) (2.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap>=0.57.1->geoai-py) (0.20.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap>=0.57.1->geoai-py) (9.1.4)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->geoai-py)
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->geoai-py)
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (2.14.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->geoai-py) (3.1.6)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub->geoai-py) (0.24.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (15.0.1)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap>=0.57.1->geoai-py) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap>=0.57.1->geoai-py)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (4.9.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->geoai-py) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->geoai-py) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->geoai-py) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.6.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (6.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.5.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.5.13)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (2.21.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.7.0)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface_hub->geoai-py) (13.9.4)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (6.5.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (25.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap>=0.57.1->geoai-py) (2.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap>=0.57.1->geoai-py) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.8.6)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets->leafmap>=0.57.1->geoai-py) (0.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface_hub->geoai-py) (4.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (2.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface_hub->geoai-py) (0.1.2)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.4.0)
# Downloading geoai_py-0.37.2-py2.py3-none-any.whl (601 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.8/601.8 kB 4.3 MB/s eta 0:00:00
# Downloading leafmap-0.62.0-py2.py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.5/667.5 kB 20.0 MB/s eta 0:00:00
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading localtileserver-1.0.0-py3-none-any.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 40.0 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.6 MB/s eta 0:00:00
# Downloading overturemaps-1.0.0-py3-none-any.whl (25 kB)
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# Downloading rioxarray-0.22.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.0 MB/s eta 0:00:00
# Downloading smoothify-0.2.2-py3-none-any.whl (16 kB)
# Downloading torchgeo-0.9.0-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 45.3 MB/s eta 0:00:00
# Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 42.7 MB/s eta 0:00:00
# Downloading ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 95.6 MB/s eta 0:00:00
# Downloading jsonargparse-4.48.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 10.3 MB/s eta 0:00:00
# Downloading jupyter_loopback-0.3.3-py3-none-any.whl (37 kB)
# Downloading lightly-1.5.23-py3-none-any.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.6/863.6 kB 48.8 MB/s eta 0:00:00
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 51.5 MB/s eta 0:00:00
# Downloading pyfiglet-1.0.4-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.4 MB/s eta 0:00:00
# Downloading pystac-1.14.3-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 17.9 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 13.9 MB/s eta 0:00:00
# Downloading xarray-2026.4.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 66.4 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 68.9 MB/s eta 0:00:00
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rio_cogeo-7.0.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.0.6-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 22.1 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.4 MB/s eta 0:00:00
# Downloading aenum-3.1.17-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 13.0 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.2 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading typeshed_client-2.11.0-py3-none-any.whl (787 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.6/787.6 kB 47.9 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 17.0 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: aenum, whitebox, typeshed-client, pyfiglet, mercantile, lightly_utils, jsonargparse, eval-type-backport, duckdb, color-operations, server-thread, pystac, overturemaps, hydra-core, xarray, morecantile, maplibre, contextily, smoothify, rioxarray, rio-tiler, rio-cogeo, ipyvue, whiteboxgui, pystac-client, ipyvuetify, planetary-computer, lightning, lightly, leafmap, segmentation-models-pytorch, torchgeo, jupyter-loopback, localtileserver, geoai-py
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
# Successfully installed aenum-3.1.17 color-operations-0.2.0 contextily-1.7.0 duckdb-1.5.2 eval-type-backport-0.3.1 geoai-py-0.37.2 hydra-core-1.3.2 ipyvue-1.12.0 ipyvuetify-1.11.3 jsonargparse-4.48.0 jupyter-loopback-0.3.3 leafmap-0.62.0 lightly-1.5.23 lightly_utils-0.0.2 lightning-2.6.1 localtileserver-1.0.0 maplibre-0.3.6 mercantile-1.2.1 morecantile-7.0.3 overturemaps-1.0.0 planetary-computer-1.0.0 pyfiglet-1.0.4 pystac-1.14.3 pystac-client-0.9.0 rio-cogeo-7.0.2 rio-tiler-9.0.6 rioxarray-0.22.0 segmentation-models-pytorch-0.5.0 server-thread-0.3.0 smoothify-0.2.2 torchgeo-0.9.0 typeshed-client-2.11.0 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2026.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import geoai
import geoai.train as gtrain
import rasterio
import geopandas as gpd
from shapely.geometry import Polygon
import geopandas as gpd
import rasterio
import torch
from torch.utils.data import DataLoader
from sklearn.metrics import r2_score, mean_absolute_error

from pathlib import Path
import xml.etree.ElementTree as ET
import json
import shutil
import glob

# import kagglehub
# from kaggle_secrets import UserSecretsClient
# import wandb

# %%
# Get secret key from Kaggle
user_secrets = UserSecretsClient()
wandb_api = user_secrets.get_secret("WANDB_API_KEY")

# Đăng nhập tự động
wandb.login(key=wandb_api)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nguyentanphuc020505 (nguyentanphuc020505-ho-chi-minh-city-university-of-techn) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
config = {
    "model_name": "fasterrcnn_resnet50_fpn_v2",
    "num_channels": 4,
    "num_classes": 2,
    "batch_size": 4,
    "num_epochs": 150,
    "learning_rate": 0.005,
    "tile_size": 512,
    "stride": 256,
    "val_split": 0.2,
    "project": "rice_seedlings_detection_counting",
    "name": "RSDC-FasterRCNN_resnet50"
}

# wandb.init(
#     project=config["project"],
#     name=config["name"],
#     config=config
# )

# %% [markdown]
# # 2. Set up the folder and file paths

# %%
DATA_DIR = Path("/kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset")

ANNOTATION_DIR = DATA_DIR / "annotations"
RAW_DIR = DATA_DIR / "raw"

WORKING_DIR = Path("/kaggle/working")

OUT_DIR = WORKING_DIR / "output"
VECTOR_DIR = WORKING_DIR / "vectors"

VECTOR_DIR.mkdir(parents=True, exist_ok=True)

print("Raw images:", len(list(RAW_DIR.glob("*.tif"))))
print("XML labels:", len(list(ANNOTATION_DIR.glob("*.xml"))))
# Out:
# Raw images: 8
# XML labels: 8

# %% [markdown]
# # 3. View the metadata of a raster
# We need to get the basic information about what a raster might look like, what is Affine Transformation (so we can change the annotations from .xml to .geojson).

# %%
ANNO_2_PATH = RAW_DIR / "2.tif"

# %%
geoai.get_raster_info(ANNO_2_PATH)
# Out:
# {'driver': 'GTiff',
#  'width': 1527,
#  'height': 1527,
#  'count': 4,
#  'dtype': 'uint8',
#  'crs': 'EPSG:3826',
#  'transform': Affine(0.005239030778695925, 0.0, 218293.41517708264,
#         0.0, -0.005239030779305829, 2658467.4298639484),
#  'bounds': BoundingBox(left=218293.41517708264, bottom=2658459.4298639484, right=218301.4151770817, top=2658467.4298639484),
#  'resolution': (0.01, 0.01),
#  'nodata': None,
#  'band_stats': [{'band': 1,
#    'min': 33.0,
#    'max': 249.0,
#    'mean': 127.35750509600386,
#    'std': 16.259917191192397},
#   {'band': 2,
#    'min': 36.0,
#    'max': 254.0,
#    'mean': 124.59662164857065,
#    'std': 17.472386102087714},
#   {'band': 3,
#    'min': 46.0,
#    'max': 230.0,
#    'mean': 122.81249064535373,
#    'std': 13.55456635998707},
#   {'band': 4, 'min': 255.0, 'max': 255.0, 'mean': 255.0, 'std': 0.0}]}

# %% [markdown]
# The raster above has width x height x bands = 1527 x 1527 x 4. And the \
# 'transform': Affine(0.005239030778695925, 0.0, 218293.41517708264, 0.0, -0.005239030779305829, 2658467.4298639484)
#
# Affine matrix has 6 key parameters: [a, b, c, d, e, f]. Based on your data, these are:
# - a: $0.005239$ (Pixel width)
# - b: $0.0$ (Row rotation/skew)
# - c: $218293.415$ (Top-Left X coordinate in meters)
# - d: $0.0$ (Column rotation/skew)
# - e: $-0.005239$ (Pixel height - negative because images draw top-to-bottom, but maps draw bottom-to-top)
# - f: $2658467.429$ (Top-Left Y coordinate in meters)
#
# Also, the top-left corner (c and f) of the image is:
# - X (Easting) = 218293.415
# - Y (Northing) = 2658467.429
#
# Use the informations above to convert the vectors from .xml to .geojson

# %% [markdown]
# # 4. Change the .xml annotation to .geojson for geoai
#
# We're going to use geoai to train the model. This requires the annotations to be in .geojson format. However, the annotations right now are in .xml format

# %% [markdown]
# This function reads a .xml file and returns a list of dictionaries. Each dictionary is an object containing information of a bbox: xmin, ymin, xmax, ymax

# %%
def parse_xml(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    ret = []

    for bbox in root.iter("bndbox"):
        info = {}
        info["xmin"] = int(bbox.find("xmin").text)
        info["ymin"] = int(bbox.find("ymin").text)
        info["xmax"] = int(bbox.find("xmax").text)
        info["ymax"] = int(bbox.find("ymax").text)

        ret.append(info)

    return ret

# %% [markdown]
# To convert any pixel coordinate $(x, y)$ to a geographic coordinate $(X, Y)$, the system applies this linear algebra formula:
# - $X = (a \cdot x) + (b \cdot y) + c$
# - $Y = (d \cdot x) + (e \cdot y) + f$
#
# But with rasterio, we can multiply the Affine object with the coordinate $(x, y)$ and get the same result

# %% [markdown]
# Convert the .xml files to .geojson

# %%
for xml in ANNOTATION_DIR.iterdir():
    xml_path = str(xml.resolve())
    if ".txt" in xml_path:
        continue

    xml_name = xml.name[0]
    raster_path = RAW_DIR / f"{xml_name}.tif"

    with rasterio.open(raster_path) as src:
        raster_crs = src.crs
        t = src.transform

    polygons = []
    for bbox in parse_xml(xml_path):
        xmin, ymin = bbox["xmin"], bbox["ymin"]
        xmax, ymax = bbox["xmax"], bbox["ymax"]

        A = t * (xmin, ymin)  # top-left
        B = t * (xmax, ymin)  # top-right
        C = t * (xmax, ymax)  # bottom-right
        D = t * (xmin, ymax)  # bottom-left

        polygons.append(Polygon([A, B, C, D, A]))

    gdf = gpd.GeoDataFrame(
        {"class": ["riceseedling"] * len(polygons)},
        geometry=polygons,
        crs=raster_crs
    )
    out_path = VECTOR_DIR / f"{xml_name}.geojson"
    gdf.to_file(out_path, driver="GeoJSON")
    print(f"{xml_name}: {len(polygons)} annotations, CRS={raster_crs}")
# Out:
# 2: 1000 annotations, CRS=EPSG:3826
# 8: 1005 annotations, CRS=EPSG:3826
# 6: 1002 annotations, CRS=EPSG:3826
# 7: 1029 annotations, CRS=EPSG:3826
# 1: 898 annotations, CRS=EPSG:3826
# 4: 985 annotations, CRS=EPSG:3826
# 3: 1019 annotations, CRS=EPSG:3826
# 5: 996 annotations, CRS=EPSG:3826

# %% [markdown]
# # 5. Train the object detection model

# %% [markdown]
# ## Create train/val data from images 1-6 and test data from images 7, 8

# %% [markdown]
# We have to chip down the image because it is too large to feed the model

# %%
# Create the temp directories
for raster_path in sorted(RAW_DIR.glob("*.tif")):
    name = raster_path.stem
    vector_path = VECTOR_DIR / f"{name}.geojson"

    print(f"Chipping:\n + raster {raster_path}\n + vector {vector_path}")
    geoai.export_geotiff_tiles(
        in_raster=raster_path,
        out_folder=OUT_DIR / name,
        in_class_data=vector_path,
        tile_size=512,
        stride=256,
        buffer_radius=0,
    )
# Out:
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/1.tif
#  + vector /kaggle/working/vectors/1.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.41it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/2.tif
#  + vector /kaggle/working/vectors/2.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.25it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/3.tif
#  + vector /kaggle/working/vectors/3.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.20it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/4.tif
#  + vector /kaggle/working/vectors/4.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.18it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/5.tif
#  + vector /kaggle/working/vectors/5.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:06<00:00,  4.16it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/6.tif
#  + vector /kaggle/working/vectors/6.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.20it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/7.tif
#  + vector /kaggle/working/vectors/7.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:06<00:00,  3.97it/s]
# Chipping:
#  + raster /kaggle/input/datasets/ngtanphuc020505/rice-seedlings-dataset/riceseedling_dataset/raw/8.tif
#  + vector /kaggle/working/vectors/8.geojson
# Generated: 25, With features: 25: 100%|██████████| 25/25 [00:05<00:00,  4.28it/s]

# %% [markdown]
# Create train/val data from images 1-6

# %%
TRAIN_IMG_DIR = OUT_DIR / "train" / "images"
TRAIN_IMG_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_LABEL_DIR = OUT_DIR / "train" / "labels"
TRAIN_LABEL_DIR.mkdir(parents=True, exist_ok=True)

count = 0
for i in range(1, 7):

    OLD_IMG_DIR = OUT_DIR / f"{i}" / "images"
    OLD_LABEL_DIR = OUT_DIR / f"{i}" / "labels"
    for img, label in zip(OLD_IMG_DIR.iterdir(), OLD_LABEL_DIR.iterdir()):
        new_name = f"tile_{"0"*(6-len(str(count)))}{count}.tif"
        shutil.copy(str(img.resolve()), TRAIN_IMG_DIR / new_name)  # copy image
        shutil.copy(str(label.resolve()), TRAIN_LABEL_DIR / new_name)  # copy label
        count += 1

    shutil.rmtree(OUT_DIR / f"{i}")  # delete the temp directory

# %% [markdown]
# Create test data from images 7, 8

# %%
TEST_IMG_DIR = OUT_DIR / "test" / "images"
TEST_IMG_DIR.mkdir(parents=True, exist_ok=True)

TEST_LABEL_DIR = OUT_DIR / "test" / "labels"
TEST_LABEL_DIR.mkdir(parents=True, exist_ok=True)

count = 0
for i in range(7, 9):

    OLD_IMG_DIR = OUT_DIR / f"{i}" / "images"
    OLD_LABEL_DIR = OUT_DIR / f"{i}" / "labels"
    for img, label in zip(OLD_IMG_DIR.iterdir(), OLD_LABEL_DIR.iterdir()):
        new_name = f"tile_{"0"*(6-len(str(count)))}{count}.tif"
        shutil.copy(str(img.resolve()), TEST_IMG_DIR / new_name)  # copy image
        shutil.copy(str(label.resolve()), TEST_LABEL_DIR / new_name)  # copy label
        count += 1

    shutil.rmtree(OUT_DIR / f"{i}")  # delete the temp directory

# %% [markdown]
# ## Train object detection model

# %%
current_epoch = 0

def patched_train_one_epoch(
    model, optimizer, data_loader, device, epoch, print_freq, scaler=None,
    orig=gtrain.train_one_epoch
):
    global current_epoch
    train_loss = orig(model, optimizer, data_loader, device, epoch, print_freq, scaler)
    current_epoch = epoch + 1
    
    # Log both scalar and full dict if possible
    wandb.log({
        "epoch": epoch, 
        "train/loss": float(train_loss)
    }, step=epoch)
    print(f"💩💩💩💩💩 Epoch {current_epoch} 💩💩💩💩💩")
    print(f"📊 W&B train loss: {float(train_loss):.4f}")
    return train_loss

def patched_evaluate(
    model, data_loader, device,
    orig=gtrain.evaluate,
    **kwargs
):
    global current_epoch
    
    # Call original evaluate
    metrics = orig(model, data_loader, device, **kwargs)
    
    log_dict = {
        "epoch": current_epoch,
        "val/loss": metrics.get("loss", 0),
        "val/IoU": metrics.get("IoU", 0),
    }
    
    # Add full COCO metrics
    try:
        coco_metrics = gtrain.evaluate_coco_metrics(
            model, data_loader, device, verbose=False
        )
        log_dict.update({
            f"val/{k}": v for k, v in coco_metrics.items()
        })
        print(f"📊 COCO mAP@0.5: {coco_metrics.get('mAP@0.5', 0):.4f} | "
              f"mAP@0.5:0.95: {coco_metrics.get('mAP@[0.5:0.95]', 0):.4f}")
    except Exception as e:
        print(f"⚠️ COCO metrics failed: {e}")
    
    # wandb.log(log_dict, step=current_epoch)
    return metrics

gtrain.train_one_epoch = patched_train_one_epoch
gtrain.evaluate = patched_evaluate
print("✅ W&B patches applied")
# Out:
# ✅ W&B patches applied

# %%
print(f"===== Total number of epochs: {config["num_epochs"]} =====")
# Out:
# ===== Total number of epochs: 150 =====

# %%
geoai.train_MaskRCNN_model(
    model_name=config["model_name"],
    images_dir=f"{OUT_DIR}/train/images",
    labels_dir=f"{OUT_DIR}/train/labels",
    output_dir=f"{OUT_DIR}/models",
    num_channels=config["num_channels"],
    pretrained=True,
    batch_size=config["batch_size"],
    num_epochs=config["num_epochs"],
    learning_rate=config["learning_rate"],
    val_split=config["val_split"],
)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 220MB/s]
# 💩💩💩💩💩 Epoch 1 💩💩💩💩💩
# 📊 W&B train loss: 2.5538
# 📊 COCO mAP@0.5: 0.3931 | mAP@0.5:0.95: 0.1174
# 💩💩💩💩💩 Epoch 2 💩💩💩💩💩
# 📊 W&B train loss: 1.1029
# 📊 COCO mAP@0.5: 0.4967 | mAP@0.5:0.95: 0.1749
# 💩💩💩💩💩 Epoch 3 💩💩💩💩💩
# 📊 W&B train loss: 0.9569
# 📊 COCO mAP@0.5: 0.6188 | mAP@0.5:0.95: 0.2176
# 💩💩💩💩💩 Epoch 4 💩💩💩💩💩
# 📊 W&B train loss: 0.9032
# 📊 COCO mAP@0.5: 0.6278 | mAP@0.5:0.95: 0.2305
# 💩💩💩💩💩 Epoch 5 💩💩💩💩💩
# 📊 W&B train loss: 0.8565
# 📊 COCO mAP@0.5: 0.6722 | mAP@0.5:0.95: 0.2497
# 💩💩💩💩💩 Epoch 6 💩💩💩💩💩
# 📊 W&B train loss: 0.8255
# 📊 COCO mAP@0.5: 0.6820 | mAP@0.5:0.95: 0.2601
# 💩💩💩💩💩 Epoch 7 💩💩💩💩💩
# 📊 W&B train loss: 0.7950
# 📊 COCO mAP@0.5: 0.6782 | mAP@0.5:0.95: 0.2681
# 💩💩💩💩💩 Epoch 8 💩💩💩💩💩
# 📊 W&B train loss: 0.7803
# 📊 COCO mAP@0.5: 0.6969 | mAP@0.5:0.95: 0.2745
# 💩💩💩💩💩 Epoch 9 💩💩💩💩💩
# 📊 W&B train loss: 0.7696
# 📊 COCO mAP@0.5: 0.6656 | mAP@0.5:0.95: 0.2663
# 💩💩💩💩💩 Epoch 10 💩💩💩💩💩
# 📊 W&B train loss: 0.7520
# 📊 COCO mAP@0.5: 0.6597 | mAP@0.5:0.95: 0.2639
# 💩💩💩💩💩 Epoch 11 💩💩💩💩💩
# 📊 W&B train loss: 0.7341
# 📊 COCO mAP@0.5: 0.7039 | mAP@0.5:0.95: 0.2894
# 💩💩💩💩💩 Epoch 12 💩💩💩💩💩
# 📊 W&B train loss: 0.7218
# 📊 COCO mAP@0.5: 0.7192 | mAP@0.5:0.95: 0.2904
# 💩💩💩💩💩 Epoch 13 💩💩💩💩💩
# 📊 W&B train loss: 0.7288
# 📊 COCO mAP@0.5: 0.6876 | mAP@0.5:0.95: 0.2818
# 💩💩💩💩💩 Epoch 14 💩💩💩💩💩
# 📊 W&B train loss: 0.7271
# 📊 COCO mAP@0.5: 0.7098 | mAP@0.5:0.95: 0.3000
# 💩💩💩💩💩 Epoch 15 💩💩💩💩💩
# 📊 W&B train loss: 0.7212
# 📊 COCO mAP@0.5: 0.7179 | mAP@0.5:0.95: 0.3001
# 💩💩💩💩💩 Epoch 16 💩💩💩💩💩
# 📊 W&B train loss: 0.7050
# 📊 COCO mAP@0.5: 0.6926 | mAP@0.5:0.95: 0.2856
# 💩💩💩💩💩 Epoch 17 💩💩💩💩💩
# 📊 W&B train loss: 0.7005
# 📊 COCO mAP@0.5: 0.7087 | mAP@0.5:0.95: 0.2917
# 💩💩💩💩💩 Epoch 18 💩💩💩💩💩
# 📊 W&B train loss: 0.6979
# 📊 COCO mAP@0.5: 0.7076 | mAP@0.5:0.95: 0.2945
# 💩💩💩💩💩 Epoch 19 💩💩💩💩💩
# 📊 W&B train loss: 0.6983
# 📊 COCO mAP@0.5: 0.7213 | mAP@0.5:0.95: 0.3071
# 💩💩💩💩💩 Epoch 20 💩💩💩💩💩
# 📊 W&B train loss: 0.6854
# 📊 COCO mAP@0.5: 0.7067 | mAP@0.5:0.95: 0.2962
# 💩💩💩💩💩 Epoch 21 💩💩💩💩💩
# 📊 W&B train loss: 0.6846
# 📊 COCO mAP@0.5: 0.7108 | mAP@0.5:0.95: 0.3011
# 💩💩💩💩💩 Epoch 22 💩💩💩💩💩
# 📊 W&B train loss: 0.6785
# 📊 COCO mAP@0.5: 0.7244 | mAP@0.5:0.95: 0.3097
# 💩💩💩💩💩 Epoch 23 💩💩💩💩💩
# 📊 W&B train loss: 0.6854
# 📊 COCO mAP@0.5: 0.6930 | mAP@0.5:0.95: 0.2864
# 💩💩💩💩💩 Epoch 24 💩💩💩💩💩
# 📊 W&B train loss: 0.6779
# 📊 COCO mAP@0.5: 0.7298 | mAP@0.5:0.95: 0.3149
# 💩💩💩💩💩 Epoch 25 💩💩💩💩💩
# 📊 W&B train loss: 0.6688
# 📊 COCO mAP@0.5: 0.7139 | mAP@0.5:0.95: 0.3077
# 💩💩💩💩💩 Epoch 26 💩💩💩💩💩
# 📊 W&B train loss: 0.6602
# 📊 COCO mAP@0.5: 0.7146 | mAP@0.5:0.95: 0.3112
# 💩💩💩💩💩 Epoch 27 💩💩💩💩💩
# 📊 W&B train loss: 0.6584
# 📊 COCO mAP@0.5: 0.7384 | mAP@0.5:0.95: 0.3149
# 💩💩💩💩💩 Epoch 28 💩💩💩💩💩
# 📊 W&B train loss: 0.6638
# 📊 COCO mAP@0.5: 0.7127 | mAP@0.5:0.95: 0.3097
# 💩💩💩💩💩 Epoch 29 💩💩💩💩💩
# 📊 W&B train loss: 0.6555
# 📊 COCO mAP@0.5: 0.7110 | mAP@0.5:0.95: 0.3003
# 💩💩💩💩💩 Epoch 30 💩💩💩💩💩
# 📊 W&B train loss: 0.6661
# 📊 COCO mAP@0.5: 0.6780 | mAP@0.5:0.95: 0.2724
# 💩💩💩💩💩 Epoch 31 💩💩💩💩💩
# 📊 W&B train loss: 0.6690
# 📊 COCO mAP@0.5: 0.6554 | mAP@0.5:0.95: 0.2547
# 💩💩💩💩💩 Epoch 32 💩💩💩💩💩
# 📊 W&B train loss: 0.6649
# 📊 COCO mAP@0.5: 0.7401 | mAP@0.5:0.95: 0.3219
# 💩💩💩💩💩 Epoch 33 💩💩💩💩💩
# 📊 W&B train loss: 0.6500
# 📊 COCO mAP@0.5: 0.7251 | mAP@0.5:0.95: 0.3158
# 💩💩💩💩💩 Epoch 34 💩💩💩💩💩
# 📊 W&B train loss: 0.6471
# 📊 COCO mAP@0.5: 0.7416 | mAP@0.5:0.95: 0.3215
# 💩💩💩💩💩 Epoch 35 💩💩💩💩💩
# 📊 W&B train loss: 0.6492
# 📊 COCO mAP@0.5: 0.7418 | mAP@0.5:0.95: 0.3228
# 💩💩💩💩💩 Epoch 36 💩💩💩💩💩
# 📊 W&B train loss: 0.6555
# 📊 COCO mAP@0.5: 0.7291 | mAP@0.5:0.95: 0.3177
# 💩💩💩💩💩 Epoch 37 💩💩💩💩💩
# 📊 W&B train loss: 0.6483
# 📊 COCO mAP@0.5: 0.7433 | mAP@0.5:0.95: 0.3231
# 💩💩💩💩💩 Epoch 38 💩💩💩💩💩
# 📊 W&B train loss: 0.6492
# 📊 COCO mAP@0.5: 0.7155 | mAP@0.5:0.95: 0.3087
# 💩💩💩💩💩 Epoch 39 💩💩💩💩💩
# 📊 W&B train loss: 0.6431
# 📊 COCO mAP@0.5: 0.7110 | mAP@0.5:0.95: 0.3030
# 💩💩💩💩💩 Epoch 40 💩💩💩💩💩
# 📊 W&B train loss: 0.6495
# 📊 COCO mAP@0.5: 0.7426 | mAP@0.5:0.95: 0.3267
# 💩💩💩💩💩 Epoch 41 💩💩💩💩💩
# 📊 W&B train loss: 0.6378
# 📊 COCO mAP@0.5: 0.7414 | mAP@0.5:0.95: 0.3269
# 💩💩💩💩💩 Epoch 42 💩💩💩💩💩
# 📊 W&B train loss: 0.6345
# 📊 COCO mAP@0.5: 0.7291 | mAP@0.5:0.95: 0.3245
# 💩💩💩💩💩 Epoch 43 💩💩💩💩💩
# 📊 W&B train loss: 0.6393
# 📊 COCO mAP@0.5: 0.7412 | mAP@0.5:0.95: 0.3260
# 💩💩💩💩💩 Epoch 44 💩💩💩💩💩
# 📊 W&B train loss: 0.6355
# 📊 COCO mAP@0.5: 0.7151 | mAP@0.5:0.95: 0.3077
# 💩💩💩💩💩 Epoch 45 💩💩💩💩💩
# 📊 W&B train loss: 0.6400
# 📊 COCO mAP@0.5: 0.7125 | mAP@0.5:0.95: 0.3054
# 💩💩💩💩💩 Epoch 46 💩💩💩💩💩
# 📊 W&B train loss: 0.6288
# 📊 COCO mAP@0.5: 0.7311 | mAP@0.5:0.95: 0.3263
# 💩💩💩💩💩 Epoch 47 💩💩💩💩💩
# 📊 W&B train loss: 0.6327
# 📊 COCO mAP@0.5: 0.7317 | mAP@0.5:0.95: 0.3254
# 💩💩💩💩💩 Epoch 48 💩💩💩💩💩
# 📊 W&B train loss: 0.6249
# 📊 COCO mAP@0.5: 0.7325 | mAP@0.5:0.95: 0.3259
# 💩💩💩💩💩 Epoch 49 💩💩💩💩💩
# 📊 W&B train loss: 0.6316
# 📊 COCO mAP@0.5: 0.7320 | mAP@0.5:0.95: 0.3224
# 💩💩💩💩💩 Epoch 50 💩💩💩💩💩
# 📊 W&B train loss: 0.6333
# 📊 COCO mAP@0.5: 0.7331 | mAP@0.5:0.95: 0.3263
# 💩💩💩💩💩 Epoch 51 💩💩💩💩💩
# 📊 W&B train loss: 0.6291
# 📊 COCO mAP@0.5: 0.7307 | mAP@0.5:0.95: 0.3246
# 💩💩💩💩💩 Epoch 52 💩💩💩💩💩
# 📊 W&B train loss: 0.6291
# 📊 COCO mAP@0.5: 0.7435 | mAP@0.5:0.95: 0.3311
# 💩💩💩💩💩 Epoch 53 💩💩💩💩💩
# 📊 W&B train loss: 0.6314
# 📊 COCO mAP@0.5: 0.7306 | mAP@0.5:0.95: 0.3218
# 💩💩💩💩💩 Epoch 54 💩💩💩💩💩
# 📊 W&B train loss: 0.6188
# 📊 COCO mAP@0.5: 0.7429 | mAP@0.5:0.95: 0.3308
# 💩💩💩💩💩 Epoch 55 💩💩💩💩💩
# 📊 W&B train loss: 0.6293
# 📊 COCO mAP@0.5: 0.7430 | mAP@0.5:0.95: 0.3301
# 💩💩💩💩💩 Epoch 56 💩💩💩💩💩
# 📊 W&B train loss: 0.6160
# 📊 COCO mAP@0.5: 0.7318 | mAP@0.5:0.95: 0.3258
# 💩💩💩💩💩 Epoch 57 💩💩💩💩💩
# 📊 W&B train loss: 0.6245
# 📊 COCO mAP@0.5: 0.7329 | mAP@0.5:0.95: 0.3269
# 💩💩💩💩💩 Epoch 58 💩💩💩💩💩
# 📊 W&B train loss: 0.6220
# 📊 COCO mAP@0.5: 0.7439 | mAP@0.5:0.95: 0.3315
# 💩💩💩💩💩 Epoch 59 💩💩💩💩💩
# 📊 W&B train loss: 0.6262
# 📊 COCO mAP@0.5: 0.7319 | mAP@0.5:0.95: 0.3249
# 💩💩💩💩💩 Epoch 60 💩💩💩💩💩
# 📊 W&B train loss: 0.6181
# 📊 COCO mAP@0.5: 0.7425 | mAP@0.5:0.95: 0.3303
# 💩💩💩💩💩 Epoch 61 💩💩💩💩💩
# 📊 W&B train loss: 0.6215
# 📊 COCO mAP@0.5: 0.7437 | mAP@0.5:0.95: 0.3326
# 💩💩💩💩💩 Epoch 62 💩💩💩💩💩
# 📊 W&B train loss: 0.6235
# 📊 COCO mAP@0.5: 0.7308 | mAP@0.5:0.95: 0.3236
# 💩💩💩💩💩 Epoch 63 💩💩💩💩💩
# 📊 W&B train loss: 0.6138
# 📊 COCO mAP@0.5: 0.7444 | mAP@0.5:0.95: 0.3332
# 💩💩💩💩💩 Epoch 64 💩💩💩💩💩
# 📊 W&B train loss: 0.6222
# 📊 COCO mAP@0.5: 0.7421 | mAP@0.5:0.95: 0.3291
# 💩💩💩💩💩 Epoch 65 💩💩💩💩💩
# 📊 W&B train loss: 0.6159
# 📊 COCO mAP@0.5: 0.7435 | mAP@0.5:0.95: 0.3329
# 💩💩💩💩💩 Epoch 66 💩💩💩💩💩
# 📊 W&B train loss: 0.6190
# 📊 COCO mAP@0.5: 0.7446 | mAP@0.5:0.95: 0.3343
# 💩💩💩💩💩 Epoch 67 💩💩💩💩💩
# 📊 W&B train loss: 0.6178
# 📊 COCO mAP@0.5: 0.7438 | mAP@0.5:0.95: 0.3323
# 💩💩💩💩💩 Epoch 68 💩💩💩💩💩
# 📊 W&B train loss: 0.6131
# 📊 COCO mAP@0.5: 0.7335 | mAP@0.5:0.95: 0.3275
# 💩💩💩💩💩 Epoch 69 💩💩💩💩💩
# 📊 W&B train loss: 0.6152
# 📊 COCO mAP@0.5: 0.7453 | mAP@0.5:0.95: 0.3341
# 💩💩💩💩💩 Epoch 70 💩💩💩💩💩
# 📊 W&B train loss: 0.6165
# 📊 COCO mAP@0.5: 0.7437 | mAP@0.5:0.95: 0.3312
# 💩💩💩💩💩 Epoch 71 💩💩💩💩💩
# 📊 W&B train loss: 0.6274
# 📊 COCO mAP@0.5: 0.7453 | mAP@0.5:0.95: 0.3338
# 💩💩💩💩💩 Epoch 72 💩💩💩💩💩
# 📊 W&B train loss: 0.6102
# 📊 COCO mAP@0.5: 0.7445 | mAP@0.5:0.95: 0.3321
# 💩💩💩💩💩 Epoch 73 💩💩💩💩💩
# 📊 W&B train loss: 0.6104
# 📊 COCO mAP@0.5: 0.7425 | mAP@0.5:0.95: 0.3287
# 💩💩💩💩💩 Epoch 74 💩💩💩💩💩
# 📊 W&B train loss: 0.6142
# 📊 COCO mAP@0.5: 0.7454 | mAP@0.5:0.95: 0.3342
# 💩💩💩💩💩 Epoch 75 💩💩💩💩💩
# 📊 W&B train loss: 0.6138
# 📊 COCO mAP@0.5: 0.7446 | mAP@0.5:0.95: 0.3322
# 💩💩💩💩💩 Epoch 76 💩💩💩💩💩
# 📊 W&B train loss: 0.6148
# 📊 COCO mAP@0.5: 0.7444 | mAP@0.5:0.95: 0.3322
# 💩💩💩💩💩 Epoch 77 💩💩💩💩💩
# 📊 W&B train loss: 0.6127
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3336
# 💩💩💩💩💩 Epoch 78 💩💩💩💩💩
# 📊 W&B train loss: 0.6099
# 📊 COCO mAP@0.5: 0.7443 | mAP@0.5:0.95: 0.3321
# 💩💩💩💩💩 Epoch 79 💩💩💩💩💩
# 📊 W&B train loss: 0.6126
# 📊 COCO mAP@0.5: 0.7444 | mAP@0.5:0.95: 0.3318
# 💩💩💩💩💩 Epoch 80 💩💩💩💩💩
# 📊 W&B train loss: 0.6121
# 📊 COCO mAP@0.5: 0.7443 | mAP@0.5:0.95: 0.3332
# 💩💩💩💩💩 Epoch 81 💩💩💩💩💩
# 📊 W&B train loss: 0.6221
# 📊 COCO mAP@0.5: 0.7464 | mAP@0.5:0.95: 0.3354
# 💩💩💩💩💩 Epoch 82 💩💩💩💩💩
# 📊 W&B train loss: 0.6202
# 📊 COCO mAP@0.5: 0.7440 | mAP@0.5:0.95: 0.3319
# 💩💩💩💩💩 Epoch 83 💩💩💩💩💩
# 📊 W&B train loss: 0.6209
# 📊 COCO mAP@0.5: 0.7463 | mAP@0.5:0.95: 0.3363
# 💩💩💩💩💩 Epoch 84 💩💩💩💩💩
# 📊 W&B train loss: 0.6080
# 📊 COCO mAP@0.5: 0.7450 | mAP@0.5:0.95: 0.3320
# 💩💩💩💩💩 Epoch 85 💩💩💩💩💩
# 📊 W&B train loss: 0.6085
# 📊 COCO mAP@0.5: 0.7442 | mAP@0.5:0.95: 0.3318
# 💩💩💩💩💩 Epoch 86 💩💩💩💩💩
# 📊 W&B train loss: 0.6090
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3345
# 💩💩💩💩💩 Epoch 87 💩💩💩💩💩
# 📊 W&B train loss: 0.6132
# 📊 COCO mAP@0.5: 0.7452 | mAP@0.5:0.95: 0.3335
# 💩💩💩💩💩 Epoch 88 💩💩💩💩💩
# 📊 W&B train loss: 0.6071
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3358
# 💩💩💩💩💩 Epoch 89 💩💩💩💩💩
# 📊 W&B train loss: 0.6111
# 📊 COCO mAP@0.5: 0.7449 | mAP@0.5:0.95: 0.3341
# 💩💩💩💩💩 Epoch 90 💩💩💩💩💩
# 📊 W&B train loss: 0.6077
# 📊 COCO mAP@0.5: 0.7449 | mAP@0.5:0.95: 0.3328
# 💩💩💩💩💩 Epoch 91 💩💩💩💩💩
# 📊 W&B train loss: 0.6167
# 📊 COCO mAP@0.5: 0.7472 | mAP@0.5:0.95: 0.3350
# 💩💩💩💩💩 Epoch 92 💩💩💩💩💩
# 📊 W&B train loss: 0.6114
# 📊 COCO mAP@0.5: 0.7451 | mAP@0.5:0.95: 0.3329
# 💩💩💩💩💩 Epoch 93 💩💩💩💩💩
# 📊 W&B train loss: 0.6117
# 📊 COCO mAP@0.5: 0.7460 | mAP@0.5:0.95: 0.3357
# 💩💩💩💩💩 Epoch 94 💩💩💩💩💩
# 📊 W&B train loss: 0.6100
# 📊 COCO mAP@0.5: 0.7445 | mAP@0.5:0.95: 0.3326
# 💩💩💩💩💩 Epoch 95 💩💩💩💩💩
# 📊 W&B train loss: 0.6104
# 📊 COCO mAP@0.5: 0.7463 | mAP@0.5:0.95: 0.3343
# 💩💩💩💩💩 Epoch 96 💩💩💩💩💩
# 📊 W&B train loss: 0.6159
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3339
# 💩💩💩💩💩 Epoch 97 💩💩💩💩💩
# 📊 W&B train loss: 0.6142
# 📊 COCO mAP@0.5: 0.7453 | mAP@0.5:0.95: 0.3330
# 💩💩💩💩💩 Epoch 98 💩💩💩💩💩
# 📊 W&B train loss: 0.6105
# 📊 COCO mAP@0.5: 0.7463 | mAP@0.5:0.95: 0.3347
# 💩💩💩💩💩 Epoch 99 💩💩💩💩💩
# 📊 W&B train loss: 0.6088
# 📊 COCO mAP@0.5: 0.7444 | mAP@0.5:0.95: 0.3323
# 💩💩💩💩💩 Epoch 100 💩💩💩💩💩
# 📊 W&B train loss: 0.6190
# 📊 COCO mAP@0.5: 0.7471 | mAP@0.5:0.95: 0.3366
# 💩💩💩💩💩 Epoch 101 💩💩💩💩💩
# 📊 W&B train loss: 0.6075
# 📊 COCO mAP@0.5: 0.7455 | mAP@0.5:0.95: 0.3338
# 💩💩💩💩💩 Epoch 102 💩💩💩💩💩
# 📊 W&B train loss: 0.6080
# 📊 COCO mAP@0.5: 0.7438 | mAP@0.5:0.95: 0.3322
# 💩💩💩💩💩 Epoch 103 💩💩💩💩💩
# 📊 W&B train loss: 0.6175
# 📊 COCO mAP@0.5: 0.7475 | mAP@0.5:0.95: 0.3361
# 💩💩💩💩💩 Epoch 104 💩💩💩💩💩
# 📊 W&B train loss: 0.6173
# 📊 COCO mAP@0.5: 0.7460 | mAP@0.5:0.95: 0.3351
# 💩💩💩💩💩 Epoch 105 💩💩💩💩💩
# 📊 W&B train loss: 0.6072
# 📊 COCO mAP@0.5: 0.7469 | mAP@0.5:0.95: 0.3361
# 💩💩💩💩💩 Epoch 106 💩💩💩💩💩
# 📊 W&B train loss: 0.6082
# 📊 COCO mAP@0.5: 0.7440 | mAP@0.5:0.95: 0.3325
# 💩💩💩💩💩 Epoch 107 💩💩💩💩💩
# 📊 W&B train loss: 0.6133
# 📊 COCO mAP@0.5: 0.7439 | mAP@0.5:0.95: 0.3328
# 💩💩💩💩💩 Epoch 108 💩💩💩💩💩
# 📊 W&B train loss: 0.6106
# 📊 COCO mAP@0.5: 0.7443 | mAP@0.5:0.95: 0.3331
# 💩💩💩💩💩 Epoch 109 💩💩💩💩💩
# 📊 W&B train loss: 0.6068
# 📊 COCO mAP@0.5: 0.7461 | mAP@0.5:0.95: 0.3359
# 💩💩💩💩💩 Epoch 110 💩💩💩💩💩
# 📊 W&B train loss: 0.6150
# 📊 COCO mAP@0.5: 0.7452 | mAP@0.5:0.95: 0.3334
# 💩💩💩💩💩 Epoch 111 💩💩💩💩💩
# 📊 W&B train loss: 0.6096
# 📊 COCO mAP@0.5: 0.7453 | mAP@0.5:0.95: 0.3332
# 💩💩💩💩💩 Epoch 112 💩💩💩💩💩
# 📊 W&B train loss: 0.6146
# 📊 COCO mAP@0.5: 0.7462 | mAP@0.5:0.95: 0.3363
# 💩💩💩💩💩 Epoch 113 💩💩💩💩💩
# 📊 W&B train loss: 0.6067
# 📊 COCO mAP@0.5: 0.7467 | mAP@0.5:0.95: 0.3345
# 💩💩💩💩💩 Epoch 114 💩💩💩💩💩
# 📊 W&B train loss: 0.6131
# 📊 COCO mAP@0.5: 0.7463 | mAP@0.5:0.95: 0.3334
# 💩💩💩💩💩 Epoch 115 💩💩💩💩💩
# 📊 W&B train loss: 0.5999
# 📊 COCO mAP@0.5: 0.7445 | mAP@0.5:0.95: 0.3327
# 💩💩💩💩💩 Epoch 116 💩💩💩💩💩
# 📊 W&B train loss: 0.6240
# 📊 COCO mAP@0.5: 0.7469 | mAP@0.5:0.95: 0.3374
# 💩💩💩💩💩 Epoch 117 💩💩💩💩💩
# 📊 W&B train loss: 0.6010
# 📊 COCO mAP@0.5: 0.7454 | mAP@0.5:0.95: 0.3339
# 💩💩💩💩💩 Epoch 118 💩💩💩💩💩
# 📊 W&B train loss: 0.6121
# 📊 COCO mAP@0.5: 0.7456 | mAP@0.5:0.95: 0.3329
# 💩💩💩💩💩 Epoch 119 💩💩💩💩💩
# 📊 W&B train loss: 0.6156
# 📊 COCO mAP@0.5: 0.7458 | mAP@0.5:0.95: 0.3348
# 💩💩💩💩💩 Epoch 120 💩💩💩💩💩
# 📊 W&B train loss: 0.6124
# 📊 COCO mAP@0.5: 0.7428 | mAP@0.5:0.95: 0.3328
# 💩💩💩💩💩 Epoch 121 💩💩💩💩💩
# 📊 W&B train loss: 0.6123
# 📊 COCO mAP@0.5: 0.7454 | mAP@0.5:0.95: 0.3352
# 💩💩💩💩💩 Epoch 122 💩💩💩💩💩
# 📊 W&B train loss: 0.6023
# 📊 COCO mAP@0.5: 0.7455 | mAP@0.5:0.95: 0.3340
# 💩💩💩💩💩 Epoch 123 💩💩💩💩💩
# 📊 W&B train loss: 0.6089
# 📊 COCO mAP@0.5: 0.7439 | mAP@0.5:0.95: 0.3325
# 💩💩💩💩💩 Epoch 124 💩💩💩💩💩
# 📊 W&B train loss: 0.6054
# 📊 COCO mAP@0.5: 0.7461 | mAP@0.5:0.95: 0.3352
# 💩💩💩💩💩 Epoch 125 💩💩💩💩💩
# 📊 W&B train loss: 0.6097
# 📊 COCO mAP@0.5: 0.7467 | mAP@0.5:0.95: 0.3334
# 💩💩💩💩💩 Epoch 126 💩💩💩💩💩
# 📊 W&B train loss: 0.6112
# 📊 COCO mAP@0.5: 0.7446 | mAP@0.5:0.95: 0.3329
# 💩💩💩💩💩 Epoch 127 💩💩💩💩💩
# 📊 W&B train loss: 0.5982
# 📊 COCO mAP@0.5: 0.7458 | mAP@0.5:0.95: 0.3351
# 💩💩💩💩💩 Epoch 128 💩💩💩💩💩
# 📊 W&B train loss: 0.6048
# 📊 COCO mAP@0.5: 0.7438 | mAP@0.5:0.95: 0.3334
# 💩💩💩💩💩 Epoch 129 💩💩💩💩💩
# 📊 W&B train loss: 0.6054
# 📊 COCO mAP@0.5: 0.7455 | mAP@0.5:0.95: 0.3333
# 💩💩💩💩💩 Epoch 130 💩💩💩💩💩
# 📊 W&B train loss: 0.6041
# 📊 COCO mAP@0.5: 0.7462 | mAP@0.5:0.95: 0.3353
# 💩💩💩💩💩 Epoch 131 💩💩💩💩💩
# 📊 W&B train loss: 0.6103
# 📊 COCO mAP@0.5: 0.7465 | mAP@0.5:0.95: 0.3362
# 💩💩💩💩💩 Epoch 132 💩💩💩💩💩
# 📊 W&B train loss: 0.6058
# 📊 COCO mAP@0.5: 0.7458 | mAP@0.5:0.95: 0.3332
# 💩💩💩💩💩 Epoch 133 💩💩💩💩💩
# 📊 W&B train loss: 0.6166
# 📊 COCO mAP@0.5: 0.7445 | mAP@0.5:0.95: 0.3348
# 💩💩💩💩💩 Epoch 134 💩💩💩💩💩
# 📊 W&B train loss: 0.6146
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3346
# 💩💩💩💩💩 Epoch 135 💩💩💩💩💩
# 📊 W&B train loss: 0.6203
# 📊 COCO mAP@0.5: 0.7463 | mAP@0.5:0.95: 0.3369
# 💩💩💩💩💩 Epoch 136 💩💩💩💩💩
# 📊 W&B train loss: 0.6036
# 📊 COCO mAP@0.5: 0.7456 | mAP@0.5:0.95: 0.3332
# 💩💩💩💩💩 Epoch 137 💩💩💩💩💩
# 📊 W&B train loss: 0.6022
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3356
# 💩💩💩💩💩 Epoch 138 💩💩💩💩💩
# 📊 W&B train loss: 0.6081
# 📊 COCO mAP@0.5: 0.7455 | mAP@0.5:0.95: 0.3349
# 💩💩💩💩💩 Epoch 139 💩💩💩💩💩
# 📊 W&B train loss: 0.6034
# 📊 COCO mAP@0.5: 0.7462 | mAP@0.5:0.95: 0.3349
# 💩💩💩💩💩 Epoch 140 💩💩💩💩💩
# 📊 W&B train loss: 0.5984
# 📊 COCO mAP@0.5: 0.7460 | mAP@0.5:0.95: 0.3345
# 💩💩💩💩💩 Epoch 141 💩💩💩💩💩
# 📊 W&B train loss: 0.6138
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3353
# 💩💩💩💩💩 Epoch 142 💩💩💩💩💩
# 📊 W&B train loss: 0.6114
# 📊 COCO mAP@0.5: 0.7471 | mAP@0.5:0.95: 0.3375
# 💩💩💩💩💩 Epoch 143 💩💩💩💩💩
# 📊 W&B train loss: 0.6115
# 📊 COCO mAP@0.5: 0.7461 | mAP@0.5:0.95: 0.3343
# 💩💩💩💩💩 Epoch 144 💩💩💩💩💩
# 📊 W&B train loss: 0.6104
# 📊 COCO mAP@0.5: 0.7446 | mAP@0.5:0.95: 0.3327
# 💩💩💩💩💩 Epoch 145 💩💩💩💩💩
# 📊 W&B train loss: 0.6105
# 📊 COCO mAP@0.5: 0.7449 | mAP@0.5:0.95: 0.3340
# 💩💩💩💩💩 Epoch 146 💩💩💩💩💩
# 📊 W&B train loss: 0.6104
# 📊 COCO mAP@0.5: 0.7464 | mAP@0.5:0.95: 0.3355
# 💩💩💩💩💩 Epoch 147 💩💩💩💩💩
# 📊 W&B train loss: 0.6218
# 📊 COCO mAP@0.5: 0.7461 | mAP@0.5:0.95: 0.3353
# 💩💩💩💩💩 Epoch 148 💩💩💩💩💩
# 📊 W&B train loss: 0.6062
# 📊 COCO mAP@0.5: 0.7457 | mAP@0.5:0.95: 0.3353
# 💩💩💩💩💩 Epoch 149 💩💩💩💩💩
# 📊 W&B train loss: 0.6074
# 📊 COCO mAP@0.5: 0.7446 | mAP@0.5:0.95: 0.3333
# 💩💩💩💩💩 Epoch 150 💩💩💩💩💩
# 📊 W&B train loss: 0.6183
# 📊 COCO mAP@0.5: 0.7460 | mAP@0.5:0.95: 0.3355
# 📊 COCO mAP@0.5: 0.7441 | mAP@0.5:0.95: 0.3297

# %% [markdown]
# Log the best model artifact after training completes

# %%
best_model_path = OUT_DIR / "models" / "best_model.pth"
if best_model_path.exists():
    artifact = wandb.Artifact(
        name=config["name"],
        type="model",
        metadata={"epochs": config["num_epochs"], "learning_rate": config["learning_rate"]}
    )
    artifact.add_file(str(best_model_path), name="best_model.pth")
    wandb.run.log_artifact(artifact)
    print("✅ best_model.pth logged to W&B")
# Out:
# ✅ best_model.pth logged to W&B

# %% [markdown]
# # 6. Evaluate the model

# %% [markdown]
# Load the best model

# %%
# Delete later
model_path = Path("../models/FasterRCNN_resnet50/best_model.pth")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model_path = OUT_DIR / "models/best_model.pth"

# Define the model architecture
model = gtrain.get_detection_model(
    model_name=config["model_name"],
    num_classes=2,
    num_channels=config["num_channels"],
    pretrained=False
)

# Load the trained weights
state_dict = torch.load(model_path, map_location=device)
model.load_state_dict(state_dict)

model.to(device)
model.eval()

print("✅ Best Model loaded successfully")
# Out:
# ✅ Best Model loaded successfully

# %%
TEST_IMG_DIR = Path("../data/geoai-dataset/test/images")
TEST_LABEL_DIR = Path("../data/geoai-dataset/test/labels")

# %%
image_paths = sorted(glob.glob(str(TEST_IMG_DIR / "*.tif")))
label_paths = sorted(glob.glob(str(TEST_LABEL_DIR / "*.tif")))

test_dataset = gtrain.ObjectDetectionDataset(
    image_paths=image_paths,
    label_paths=label_paths,
    transforms=gtrain.get_transform(train=False),
    num_channels=config["num_channels"]
)

test_loader = DataLoader(
    test_dataset,
    batch_size=4,
    shuffle=False,
    collate_fn=gtrain.collate_fn,
    num_workers=2
)

print(f"✅ Test loader created with {len(test_dataset)} images")
# Out:
# ✅ Test loader created with 50 images

# %% [markdown]
# Evaluate the model

# %%
basic_metrics = gtrain.evaluate(
    model=model,
    data_loader=test_loader,
    device=device,
    use_mask_iou=False  # true for Mask R-CNN
)

# %%
coco_metrics = gtrain.evaluate_coco_metrics(
    model=model,
    data_loader=test_loader,
    device=device,
    class_names=["riceseedling"],
    verbose=True
)
# Out:
# 100%|██████████| 13/13 [00:04<00:00,  2.71it/s]

# %%
def evaluate_counting(model, data_loader, device):
    preds_count = []
    gts_count = []
    
    for images, targets in data_loader:
        images = [img.to(device) for img in images]
        outputs = model(images)
        
        for out, tgt in zip(outputs, targets):
            pred_count = len(out["boxes"])
            gt_count = len(tgt["boxes"])
            preds_count.append(pred_count)
            gts_count.append(gt_count)
    
    r2 = r2_score(gts_count, preds_count)
    rmse = np.sqrt(mean_absolute_error(gts_count, preds_count))
    mape = np.mean(np.abs((np.array(gts_count) - np.array(preds_count)) / np.array(gts_count))) * 100

    return (r2, rmse, mape)

# %%
print("\n" + "="*40)
print("FINAL TEST RESULTS")
print("="*40)
print(f"IoU: {basic_metrics.get('IoU', 0):.4f}")
for k, v in coco_metrics.items():
    print(f"{k:15}: {v:.4f}")

r2, rmse, mape = evaluate_counting(model, test_loader, device)
print(f"Counting -> R2: {r2:.4f} | RMSE: {rmse:.2f} | MAPE: {mape:.2f}%")
# Out:
# ========================================
# FINAL TEST RESULTS
# ========================================
# IoU: 0.5762
# AP@0.5/riceseedling: 0.7038
# mAP@0.5        : 0.7038
# mAP@0.75       : 0.1076
# mAP@[0.5:0.95] : 0.2494
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[14], line 8
#       4 print(f"IoU: {basic_metrics.get('IoU', 0):.4f}")
#       5 for k, v in coco_metrics.items():
#       6     print(f"{k:15}: {v:.4f}")
#       7
# ----> 8 r2, rmse, mape = evaluate_counting(model, test_loader, device)
#       9 print(f"Counting -> R2: {r2:.4f} | RMSE: {rmse:.2f} | MAPE: {mape:.2f}%")
#
# Cell In[10], line 7, in evaluate_counting(model, data_loader, device)
#       3     gts_count = []
#       4
#       5     for images, targets in data_loader:
#       6         images = [img.to(device) for img in images]
# ----> 7         outputs = model(images)
#       8
#       9         for out, tgt in zip(outputs, targets):
#      10             pred_count = len(out["boxes"])
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torchvision/models/detection/generalized_rcnn.py:114, in GeneralizedRCNN.forward(self, images, targets)
#     107             degen_bb: list[float] = boxes[bb_idx].tolist()
#     108             torch._assert(
#     109                 False,
#     110                 "All bounding boxes should have positive height and width."
#     111                 f" Found invalid box {degen_bb} for target at index {target_idx}.",
#     112             )
# --> 114 features = self.backbone(images.tensors)
#     115 if isinstance(features, torch.Tensor):
#     116     features = OrderedDict([("0", features)])
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torchvision/models/detection/backbone_utils.py:57, in BackboneWithFPN.forward(self, x)
#      56 def forward(self, x: Tensor) -> dict[str, Tensor]:
# ---> 57     x = self.body(x)
#      58     x = self.fpn(x)
#      59     return x
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torchvision/models/_utils.py:69, in IntermediateLayerGetter.forward(self, x)
#      67 out = OrderedDict()
#      68 for name, module in self.items():
# ---> 69     x = module(x)
#      70     if name in self.return_layers:
#      71         out_name = self.return_layers[name]
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Python_Projects/RSDC/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 158.00 MiB. GPU 0 has a total capacity of 5.67 GiB of which 99.31 MiB is free. Including non-PyTorch memory, this process has 5.54 GiB memory in use. Of the allocated memory 5.23 GiB is allocated by PyTorch, and 175.32 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %% [markdown]
# ## Finish the wandb run

# %%
wandb.finish()
